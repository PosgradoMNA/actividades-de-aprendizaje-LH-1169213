# %% [markdown]
# <a href="https://colab.research.google.com/github/PosgradoMNA/actividades-de-aprendizaje-LH-1169213/blob/main/W8_IBM_MOD5_A01169213.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Semana 8: Data Analysis with Python (IBM)
# # Módulo 5: Model evaluation
# ## Laura Elena Hernández Mata
# ## A01169213
# ### Ciencia y analítica de datos (TC4029.10)
# ### Dra. María de la Paz Rico Fernández
#
# 9 noviembre 2022

# %% [markdown]
# # Módulo 5

# %% [markdown]
# Contenido del curso:
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #**Model evaluation**

# %% [markdown]
# Verificar que nuestro modelo puede ser utilizado en el mundo real.
#
# Esto se realiza a través de la partición de datos en train y test. Se espera que la data de entrenamiento sea mayor que la de test.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Para dividir la información usamos train_test_split, tal como se muestra a continuación:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Para poder comprobar que el modelo funciona correctamente, se puede utilizar el generalizing error, el cual mide qué tan bien se está realizando la predicción.  En la siguientes gráficas se muestra la distribución de la regresión lineal en azul y el resultado del entrenamiento a la izquierda; mientras que a la derecha vemos la misma relación, pero con los datos de test.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Cross validation
#
# Divide la información en cierta cantidad de grupos, esto para entrenamiento y validación. Logra que se utilice toda la información para train y test:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Y la función se realiza de la siguiente manera:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Para predecir la información, se utiliza lo siguiente:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Over & under fit, model seleccion**

# %% [markdown]
# Underfit: the model is too simple to fin the data
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Si se incrementa un grado, sigue sin hacer un perfect fit
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Cuando se llega al grado 8, el ajuste es perfecto
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Overfit: El modelo es demasiado complejo para la data, por ejemplo, en el grado 16
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Cuando se grafica el error por el orden, se encuentran las siguientes líneas de test y train. Podemos apreciar que el mejor es el de grado 8. Underfit es del lado izquierdo y overfit es del lado derecho.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Una fuente del error puede ser el ruido, que no se puede predecir y no se sabe cómo será su comportamiento
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Con R^2 podemos saber también qué tan sub o sobreentrenado está el modelo. Mientras más se acerque R^2 a 1, más accurate es el modelo.
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Para calcularlo se hace lo siguiente:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Ridge regression**

# %% [markdown]
# Prevents overfitting

# %% [markdown]
# Alfa es un parámetro que seleccionamos antes de entrenar el modelo. Si es muy grande, los coeficientes se acercarán a 0 y va a resultar en subentrenamiento.
#
# Pero si Alfa es muy chico, comienza a sobreentrenarse.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Cuando alfa es igual a 1, se empieza a ver el subentrenamiento de forma evidente: ![image.png](data:image/png;base64,...)

# %% [markdown]
# Regresión de ridge
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Cuando alfa incrementa, R^2 decrece
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Grid search - Hiperparámetros**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# En cada iteración o modelo, se debe de buscar disminuir el error y/o maximizar R^2.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Un ejemplo de cómo obtenerlo:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # LAB

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/module_5_auto.csv'

# %%
df = pd.read_csv(path)

# %%
df.to_csv('module_5_auto.csv')

# %%
df=df._get_numeric_data()
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  symboling  normalized-losses  wheel-base  \
# 0           0             0          3                122        88.6
# 1           1             1          3                122        88.6
# 2           2             2          1                122        94.5
# 3           3             3          2                164        99.8
# 4           4             4          2                164        99.4
#
#      length     width  height  curb-weight  engine-size  ...  stroke  \
# 0  0.811148  0.890278    48.8         2548          130  ...    2.68
# 1  0.811148  0.890278    48.8         2548          130  ...    2.68
# 2  0.822681  0.909722    52.4         2823          152  ...    3.47
# 3  0.848630  0.919444    54.3         2337          109  ...    3.40
# 4  0.848630  0.922222    54.3         2824          136  ...    3.40
#
#    compression-ratio  horsepower  peak-rpm  city-mpg  highway-mpg    price  \
# ...

# %%
from ipywidgets import interact, interactive, fixed, interact_manual

# %%
def DistributionPlot(RedFunction, BlueFunction, RedName, BlueName, Title):
    width = 12
    height = 10
    plt.figure(figsize=(width, height))

    ax1 = sns.distplot(RedFunction, hist=False, color="r", label=RedName)
    ax2 = sns.distplot(BlueFunction, hist=False, color="b", label=BlueName, ax=ax1)

    plt.title(Title)
    plt.xlabel('Price (in dollars)')
    plt.ylabel('Proportion of Cars')

    plt.show()
    plt.close()

# %%
def PollyPlot(xtrain, xtest, y_train, y_test, lr,poly_transform):
    width = 12
    height = 10
    plt.figure(figsize=(width, height))
    
    
    #training data 
    #testing data 
    # lr:  linear regression object 
    #poly_transform:  polynomial transformation object 
 
    xmax=max([xtrain.values.max(), xtest.values.max()])

    xmin=min([xtrain.values.min(), xtest.values.min()])

    x=np.arange(xmin, xmax, 0.1)


    plt.plot(xtrain, y_train, 'ro', label='Training Data')
    plt.plot(xtest, y_test, 'go', label='Test Data')
    plt.plot(x, lr.predict(poly_transform.fit_transform(x.reshape(-1, 1))), label='Predicted Function')
    plt.ylim([-10000, 60000])
    plt.ylabel('Price')
    plt.legend()

# %% [markdown]
# ## Part 1: Training and Testing

# %%
y_data = df['price']

# %%
x_data=df.drop('price',axis=1)

# %%
from sklearn.model_selection import train_test_split


x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.10, random_state=1)


print("number of test samples :", x_test.shape[0])
print("number of training samples:",x_train.shape[0])
# Out:
# number of test samples : 21
# number of training samples: 180

# %% [markdown]
# Question #1):
# Use the function "train_test_split" to split up the dataset such that 40% of the data samples will be utilized for testing. Set the parameter "random_state" equal to zero. The output of the function should be the following: "x_train1" , "x_test1", "y_train1" and "y_test1".

# %%
x_train1, x_test1, y_train1, y_test1 = train_test_split(x_data, y_data, test_size=0.4, random_state=0) 
print("number of test samples :", x_test1.shape[0])
print("number of training samples:",x_train1.shape[0])
# Out:
# number of test samples : 81
# number of training samples: 120

# %%
from sklearn.linear_model import LinearRegression

# %%
lre=LinearRegression()

# %%
lre.fit(x_train[['horsepower']], y_train)
# Out:
# LinearRegression()

# %%
lre.score(x_test[['horsepower']], y_test)
# Out:
# 0.36358755750788263

# %%
lre.score(x_train[['horsepower']], y_train)
# Out:
# 0.6619724197515104

# %% [markdown]
# Question #2):
# Find the R^2 on the test data using 40% of the dataset for testing.

# %%
x_train1, x_test1, y_train1, y_test1 = train_test_split(x_data, y_data, test_size=0.4, random_state=0)
lre.fit(x_train1[['horsepower']],y_train1)
lre.score(x_test1[['horsepower']],y_test1)
# Out:
# 0.7139364665406973

# %% [markdown]
# Cross-Validation Score

# %%
from sklearn.model_selection import cross_val_score

# %%
Rcross = cross_val_score(lre, x_data[['horsepower']], y_data, cv=4)

# %%
Rcross
# Out:
# array([0.7746232 , 0.51716687, 0.74785353, 0.04839605])

# %%
print("The mean of the folds are", Rcross.mean(), "and the standard deviation is" , Rcross.std())
# Out:
# The mean of the folds are 0.522009915042119 and the standard deviation is 0.291183944475603

# %%
-1 * cross_val_score(lre,x_data[['horsepower']], y_data,cv=4,scoring='neg_mean_squared_error')
# Out:
# array([20254142.84026702, 43745493.2650517 , 12539630.34014931,
#        17561927.72247591])

# %% [markdown]
# Question #3):
# Calculate the average R^2 using two folds, then find the average R^2 for the second fold utilizing the "horsepower" feature:

# %%
Rc=cross_val_score(lre,x_data[['horsepower']], y_data,cv=2)
Rc.mean()
# Out:
# 0.5166761697127429

# %%
from sklearn.model_selection import cross_val_predict

# %%
yhat = cross_val_predict(lre,x_data[['horsepower']], y_data,cv=4)
yhat[0:5]
# Out:
# array([14141.63807508, 14141.63807508, 20814.29423473, 12745.03562306,
#        14762.35027598])

# %% [markdown]
# Part 2: Overfitting, Underfitting and Model Selection

# %%
lr = LinearRegression()
lr.fit(x_train[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']], y_train)
# Out:
# LinearRegression()

# %%
yhat_train = lr.predict(x_train[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']])
yhat_train[0:5]
# Out:
# array([ 7426.6731551 , 28323.75090803, 14213.38819709,  4052.34146983,
#        34500.19124244])

# %%
yhat_test = lr.predict(x_test[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']])
yhat_test[0:5]
# Out:
# array([11349.35089149,  5884.11059106, 11208.6928275 ,  6641.07786278,
#        15565.79920282])

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
Title = 'Distribution  Plot of  Predicted Value Using Training Data vs Training Data Distribution'
DistributionPlot(y_train, yhat_train, "Actual Values (Train)", "Predicted Values (Train)", Title)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
Title='Distribution  Plot of  Predicted Value Using Test Data vs Data Distribution of Test Data'
DistributionPlot(y_test,yhat_test,"Actual Values (Test)","Predicted Values (Test)",Title)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
from sklearn.preprocessing import PolynomialFeatures

# %% [markdown]
# Overfitting

# %%
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.45, random_state=0)

# %%
pr = PolynomialFeatures(degree=5)
x_train_pr = pr.fit_transform(x_train[['horsepower']])
x_test_pr = pr.fit_transform(x_test[['horsepower']])
pr
# Out:
# PolynomialFeatures(degree=5)

# %%
poly = LinearRegression()
poly.fit(x_train_pr, y_train)
# Out:
# LinearRegression()

# %%
yhat = poly.predict(x_test_pr)
yhat[0:5]
# Out:
# array([ 6728.65561887,  7307.98782321, 12213.78770965, 18893.24804015,
#        19995.95195136])

# %%
print("Predicted values:", yhat[0:4])
print("True values:", y_test[0:4].values)
# Out:
# Predicted values: [ 6728.65561887  7307.98782321 12213.78770965 18893.24804015]
# True values: [ 6295. 10698. 13860. 13499.]

# %%
PollyPlot(x_train[['horsepower']], x_test[['horsepower']], y_train, y_test, poly,pr)

# %%
poly.score(x_train_pr, y_train)
# Out:
# 0.556771690212023

# %%
poly.score(x_test_pr, y_test)
# Out:
# -29.87134030204415

# %%
Rsqu_test = []

order = [1, 2, 3, 4]
for n in order:
    pr = PolynomialFeatures(degree=n)
    
    x_train_pr = pr.fit_transform(x_train[['horsepower']])
    
    x_test_pr = pr.fit_transform(x_test[['horsepower']])    
    
    lr.fit(x_train_pr, y_train)
    
    Rsqu_test.append(lr.score(x_test_pr, y_test))

plt.plot(order, Rsqu_test)
plt.xlabel('order')
plt.ylabel('R^2')
plt.title('R^2 Using Test Data')
plt.text(3, 0.75, 'Maximum R^2 ')
# Out:
# Text(3, 0.75, 'Maximum R^2 ')

# %%
def f(order, test_data):
    x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=test_data, random_state=0)
    pr = PolynomialFeatures(degree=order)
    x_train_pr = pr.fit_transform(x_train[['horsepower']])
    x_test_pr = pr.fit_transform(x_test[['horsepower']])
    poly = LinearRegression()
    poly.fit(x_train_pr,y_train)
    PollyPlot(x_train[['horsepower']], x_test[['horsepower']], y_train,y_test, poly, pr)

# %%
interact(f, order=(0, 6, 1), test_data=(0.05, 0.95, 0.05))
# Out:
# interactive(children=(IntSlider(value=3, description='order', max=6), FloatSlider(value=0.45, description='tes…
# <function __main__.f(order, test_data)>

# %% [markdown]
# Question #4a):
# We can perform polynomial transformations with more than one feature. Create a "PolynomialFeatures" object "pr1" of degree two.

# %%
pr1=PolynomialFeatures(degree=2)

# %% [markdown]
# Question #4b):
# Transform the training and testing samples for the features 'horsepower', 'curb-weight', 'engine-size' and 'highway-mpg'. Hint: use the method "fit_transform".

# %%
x_train_pr1=pr1.fit_transform(x_train[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']])

x_test_pr1=pr1.fit_transform(x_test[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']])

# %% [markdown]
# Question #4c):
# How many dimensions does the new feature have? Hint: use the attribute "shape".

# %%
x_train_pr1.shape #there are now 15 features
# Out:
# (110, 15)

# %% [markdown]
# Question #4d):
# Create a linear regression model "poly1". Train the object using the method "fit" using the polynomial features.

# %%
poly1=LinearRegression().fit(x_train_pr1,y_train)

# %% [markdown]
# Question #4e):
# Use the method "predict" to predict an output on the polynomial features, then use the function "DistributionPlot" to display the distribution of the predicted test output vs. the actual test data.

# %%
yhat_test1=poly1.predict(x_test_pr1)

Title='Distribution  Plot of  Predicted Value Using Test Data vs Data Distribution of Test Data'

DistributionPlot(y_test, yhat_test1, "Actual Values (Test)", "Predicted Values (Test)", Title)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Question #4f):
# Using the distribution plot above, describe (in words) the two regions where the predicted prices are less accurate than the actual prices.

# %% [markdown]
# El valor predecido es mayor que el valor actual para autos del rango de precio de 10k, esto en comparación a los que se encuentran entre 30 y 40k. Por lo tanto, no es adecuado en esos rangos.

# %% [markdown]
# ## Part 3: Ridge Regression

# %%
pr=PolynomialFeatures(degree=2)
x_train_pr=pr.fit_transform(x_train[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg','normalized-losses','symboling']])
x_test_pr=pr.fit_transform(x_test[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg','normalized-losses','symboling']])

# %%
from sklearn.linear_model import Ridge

# %%
RigeModel=Ridge(alpha=1)

# %%
RigeModel.fit(x_train_pr, y_train)
# Out:
# Ridge(alpha=1)

# %%
yhat = RigeModel.predict(x_test_pr)

# %%
print('predicted:', yhat[0:4])
print('test set :', y_test[0:4].values)
# Out:
# predicted: [ 6570.82441941  9636.2489147  20949.92322737 19403.60313256]
# test set : [ 6295. 10698. 13860. 13499.]

# %%
from tqdm import tqdm

Rsqu_test = []
Rsqu_train = []
dummy1 = []
Alpha = 10 * np.array(range(0,1000))
pbar = tqdm(Alpha)

for alpha in pbar:
    RigeModel = Ridge(alpha=alpha) 
    RigeModel.fit(x_train_pr, y_train)
    test_score, train_score = RigeModel.score(x_test_pr, y_test), RigeModel.score(x_train_pr, y_train)
    
    pbar.set_postfix({"Test Score": test_score, "Train Score": train_score})

    Rsqu_test.append(test_score)
    Rsqu_train.append(train_score)
# Out:
# 100%|██████████| 1000/1000 [00:08<00:00, 123.57it/s, Test Score=0.564, Train Score=0.859]

# %%
width = 12
height = 10
plt.figure(figsize=(width, height))

plt.plot(Alpha,Rsqu_test, label='validation data  ')
plt.plot(Alpha,Rsqu_train, 'r', label='training Data ')
plt.xlabel('alpha')
plt.ylabel('R^2')
plt.legend()

# %% [markdown]
# Question #5):
# Perform Ridge regression. Calculate the R^2 using the polynomial features, use the training data to train the model and use the test data to test the model. The parameter alpha should be set to 10.

# %%
RigeModel = Ridge(alpha=10) 
RigeModel.fit(x_train_pr, y_train)
RigeModel.score(x_test_pr, y_test)
# Out:
# 0.5418576440206702

# %% [markdown]
# ## Part 4: Grid Search

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters1= [{'alpha': [0.001,0.1,1, 10, 100, 1000, 10000, 100000, 100000]}]
parameters1
# Out:
# [{'alpha': [0.001, 0.1, 1, 10, 100, 1000, 10000, 100000, 100000]}]

# %%
RR=Ridge()
RR
# Out:
# Ridge()

# %%
Grid1 = GridSearchCV(RR, parameters1,cv=4)

# %%
Grid1.fit(x_data[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']], y_data)
# Out:
# GridSearchCV(cv=4, estimator=Ridge(),
#              param_grid=[{'alpha': [0.001, 0.1, 1, 10, 100, 1000, 10000, 100000,
#                                     100000]}])

# %%
BestRR=Grid1.best_estimator_
BestRR
# Out:
# Ridge(alpha=10000)

# %%
BestRR.score(x_test[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']], y_test)
# Out:
# 0.8411649831036151

# %% [markdown]
# Avance
#
# ![image.png](data:image/png;base64,...)
