# %% [markdown]
# <a href="https://colab.research.google.com/github/PosgradoMNA/actividades-de-aprendizaje-LH-1169213/blob/main/Module3_IBM_Activity2_Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('assignment01 for GitJobish03 and edited in git, and 18')
# Out:
# assignment01 for GitJobish03 and edited in git, and 18

# %% [markdown]
# # Módulo 3
# ## Actividad 2 / Semana 2
# ### Laura Elena Hernández Mata A01169213

# %% [markdown]
# # Tema 1 - Reading files with open
#
# Open function to create file object & obtain TXT value

# %% [markdown]
# ## Operar con el archivo
#
# File = open("file_path_and_name.txt",**mode**)
#
# Common **modes** (sólo se usa la letra):
#
# *   r -> reading
# *   w -> writing
# *   a -> appending
#
#
# ```
# File1 = open("file_path_and_name.txt",w)
# ```
#
# **File1.read()** -> para leer el archivo
#
# **File1.name()**-> String with name of file
#
# **File1.mode()** -> "r" is shown representing read
#
# **File1.close()** -> para cerrar el documento; se tiene que hacer cada vez que se abre // *alternativa a continuación para que sea automático*
#
# ## Código para abrir archivo, realizar operaciones y cerrarlo en automático.
#
# ```
# # Alternativa para cerrar automáticamente el programa
#
# with open("file_path_and_name.txt","r" as File1:
#   #Operations that will be run:
#   file_stuff=File1.read() # Stores the content of file in the variable file_stuff
#   print(file_stuff)
# #End of the block, close file object:
# print(File1.closed)
# print(file_stuff) # Esto va a imprimir cada línea de resultado, si se examina, traerá el resultado con \n que indica el salto de línea
#
# ```
#
# El **resultado** lo dará de la siguiente manera:
#
#
# > This is line 1
#
# >  This is line 2
#
# >  This is line 3
#
#
# Para conocer el **contenido del archivo por línea** se realiza lo siguiente:
#
# ```
# with open("file_path_and_name.txt","r") as File1
#   file_stuff=File1.readlines()
#   print(file_stuff)
# ```
# El **resultado** se va a dar de la siguiente manera:
#
# > file_stuff: ["This is line 1\n", "This is line 2 \n", "This is line 3"]
#
# ```
# # Para acceder a los elementos de la lista de manera individual, se puede utilizar el índice
#
# file_stuff[0] #Para la línea 1
#
# ```
# Este método también sirve para traer información de las líneas si se utiliza un índice:
# ![image.png](data:image/png;base64,...)
#
# Ejemplo de código:
#
#
# ```
# when open["file_path_and_name.txt","r"] as File1
#   file_stuff=File1.readlines(16)
#   print(file_stuff)
#   file_stuff=File1.readlines(5)
#   print(file_stuff)
#   file_stuff=File1.readlines(9)
#   print(file_stuff)
# ```
#
#
# Para lograr esto, se tendrían que correr **3 veces** el código y el **resultado** sería el siguiente:
#
# ![image.png](data:image/png;base64,...)
#
# Para leer **la primera línea** del archivo, se utiliza el siguiente código:
#
# ```
# with open("file_path_and_name.txt","r") as File1
#   file_stuff=File1.readline() #Se guarda la primera fila del archivo en la variable file_stuff
#   print(file_stuff)
# ```
#
# Para leer **línea por línea manualmente**, se corre el mismo código varias veces:
#
# ```
# with open("file_path_and_name.txt","r") as File1
#   file_stuff=File1.readlines() #Se guarda la __primera__ fila del archivo en la variable file_stuff
#   print(file_stuff)
#   file_stuff=File1.readlines() #Se guarda la __segunda__ fila del archivo en la variable file_stuff
#   print(file_stuff)
#
# ```
#
# Para leer **línea por línea automáticamente se usa loop**:
#
# ```
# with open("file_path_and_name.txt","r") as File1
#   for line in File1:
#     pirnt(line)
#
# ```

# %% [markdown]
# # Lab 1 - Module 4
# ## PY0101EN-4-1
# ### Read files Python

# %% [markdown]
# ### Download data (Posibilidades de código)

# %% [markdown]
# En el ejercicio, se muestran los siguientes ejemplos de código que **no me funcionaron para importar aquí**, pero los agrego como notas por si son útiles en algún otro momento:
#
# Cuando se trabaja en local:
#
# ```
# ## Uncomment these if working locally, else let the following code cell run.
#
# # import urllib.request
# # url = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/Module%204/data/example1.txt'
# # filename = 'Example1.txt'
# # urllib.request.urlretrieve(url, filename)
#
# ## Download Example file
# # !wget -O /resources/data/Example1.txt https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/Module%204/data/example1.txt
#
# ```
# Código del Lab:
#
# ```
# # Según el Lab, es para download data
#
# from pyodide.http import pyfetch
# import pandas as pd
#
# filename = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/Module%204/data/example1.txt"
#
# async def download(url, filename):
#     response = await pyfetch(url)
#     if response.status == 200:
#         with open(filename, "wb") as f:
#             f.write(await response.bytes())
#
#
# await download(filename, "Example1.txt")
# ```
#
# Código que sí me funcionó (se implementó en la sección "Reading text files"
#
#
# ```
# # Código para importar desde url
#
# import pandas as pd
# import urllib.request
# url = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/Module%204/data/example1.txt'
# filename = 'Example1.txt'
# urllib.request.urlretrieve(url, filename)
# ```

# %% [markdown]
# ### Reading text files (RESULTADOS DEL LAB)

# %%
import pandas as pd
import urllib.request
url = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/Module%204/data/example1.txt'
filename = 'Example1.txt'
urllib.request.urlretrieve(url, filename)
# Out:
# ('Example1.txt', <http.client.HTTPMessage at 0x7f50d20e26d0>)

# %%
example1 = "Example1.txt"
file1 = open(example1, "r")

# %%
file1.name
# Out:
# 'Example1.txt'

# %%
file1.mode
# Out:
# 'r'

# %%
FileContent = file1.read()
FileContent
# Out:
# 'This is line 1 \nThis is line 2\nThis is line 3'

# %%
print(FileContent)
# Out:
# This is line 1
# This is line 2
# This is line 3

# %%
type(FileContent)
# Out:
# str

# %%
file1.close()
file1.closed
# Out:
# True

# %% [markdown]
# ### A better way to open a file (RESULTADOS DEL LAB)

# %%
with open(example1, "r") as file1:
    FileContent = file1.read()
    print(FileContent)
# Out:
# This is line 1
# This is line 2
# This is line 3

# %%
file1.closed
# Out:
# True

# %%
print(FileContent)
# Out:
# This is line 1
# This is line 2
# This is line 3

# %%
with open(example1, "r") as file1:
    print(file1.read(4))
# Out:
# This

# %%
with open(example1, "r") as file1:
    print(file1.read(4))
    print(file1.read(4))
    print(file1.read(7))
    print(file1.read(15))
# Out:
# This
#  is
# line 1
#
# This is line 2

# %%
with open(example1, "r") as file1:
    print(file1.read(16))
    print(file1.read(5))
    print(file1.read(9))
# Out:
# This is line 1
#
# This
# is line 2

# %%
with open(example1, "r") as file1:
    print("first line: " + file1.readline())
# Out:
# first line: This is line 1

# %%
with open(example1, "r") as file1:
    print(file1.readline(20)) # does not read past the end of line
    print(file1.read(20)) # Returns the next 20 chars
# Out:
# This is line 1
#
# This is line 2
# This

# %%
with open(example1,"r") as file1:
        i = 0;
        for line in file1:
            print("Iteration", str(i), ": ", line)
            i = i + 1
# Out:
# Iteration 0 :  This is line 1
#
# Iteration 1 :  This is line 2
#
# Iteration 2 :  This is line 3

# %%
with open(example1, "r") as file1:
    FileasList = file1.readlines()

# %%
FileasList[0]
# Out:
# 'This is line 1 \n'

# %% [markdown]
# ### Print the second line

# %%
FileasList[2]
# Out:
# 'This is line 3'

# %% [markdown]
# # Tema 2 - Writing Files w/open
#
# Write to files with open function

# %% [markdown]
# ## Write data to the file
#
# **Escribir** en el file iniciando por abrir con with para que sea el cerrado en automático
#
# ```
# #This creates a file in your directory.
#
# with open("File.txt","w") as File1:
# File1.write("This is A") #The argument is the text you will input into the file
#
# ```
#
# Cada vez que se llama, va a **escribir una nueva línea** dentro del archivo
#
# ```
# with open("File.txt","w") as File1:
# File1.write("This is A\n")
# File1.write("This is B\n") #Después va a cerrar el archivo
#
# ```
#
# Escribir **elementos de una lista** con with command y **loop**
#
# ```
# Lines = ["This is line A\n", "This is line B\n", "This is line C\n"]
#
# with open("File.txt","w") as File1:
#   for line in Lines: #For loop para leer cada elemento de la lista
#     File1.write(line) #Para la primera iteración, el loop escribe el primer elemento de la lista
#     # En la segunda iteración se va a escribir el siguiente elemento
#     # Al final del loop el archivo se va a cerrar.
#
# ```
#
# Ejemplo de **resultado**:
#
# ![image.png](data:image/png;base64,...)
#
# Modo **appended**, el cual no va a crear un nuevo archivo, sino que **va a usar el file existente**
#
# ```
# with open("File.txt","a") as File1:
#   File1.write("This is line C") #va a escribir esto en el archivo y luego lo va a cerrar
# ```
# Ejemplo de **resultado**:
#
# ![image.png](data:image/png;base64,...)
#
# **Copiar** un archivo dentro de un nuevo archivo
#
# **Paso 1:** leer el file a copiar para interactuar con él
# **Paso 2:** crear un nuevo archivo
# **Paso 3:** con el loop, vamos a copiar el contenido de un archivo en el otro. *Nota: cada iteración va a copiar cada línea*
#
# ```
# with open("Example1.txt","r") as readfile:      #Paso 1
#   with open("Example3.txt", "w") as ritefile:   #Paso 2
#     for line in readfiles:                      #Paso 3 loop
#       writefile.write(line)                     #Paso 3 parte que escribe cada línea
# #Al final, cuando termine de copiar va a cerrar el archivo.
#
# ```
# Ejemplo de **resultado**:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Lab 2 - Module 4
# ## PY0101EN-4-2
# ### Write & save files in Python

# %% [markdown]
# ### Writing files

# %%
exmp2 = 'Example2.txt'
with open(exmp2, 'w') as writefile:
    writefile.write("This is line A")

# %%
with open(exmp2, 'r') as testwritefile:
    print(testwritefile.read())
# Out:
# This is line A

# %%
with open(exmp2, 'w') as writefile:
    writefile.write("This is line A\n")
    writefile.write("This is line B\n")

# %%
with open(exmp2, 'r') as testwritefile:
    print(testwritefile.read())
# Out:
# This is line A
# This is line B

# %%
Lines = ["This is line A\n", "This is line B\n", "This is line C\n"]
Lines
# Out:
# ['This is line A\n', 'This is line B\n', 'This is line C\n']

# %%
with open('Example2.txt', 'w') as writefile:
    for line in Lines:
        print(line)
        writefile.write(line)
# Out:
# This is line A
#
# This is line B
#
# This is line C

# %%
with open('Example2.txt', 'r') as testwritefile:
    print(testwritefile.read())
# Out:
# This is line A
# This is line B
# This is line C

# %%
with open('Example2.txt', 'w') as writefile:
    writefile.write("Overwrite\n")
with open('Example2.txt', 'r') as testwritefile:
    print(testwritefile.read())
# Out:
# Overwrite

# %% [markdown]
# ### Appending files

# %%
with open('Example2.txt', 'a') as testwritefile:
    testwritefile.write("This is line C\n")
    testwritefile.write("This is line D\n")
    testwritefile.write("This is line E\n")

# %%
with open('Example2.txt', 'r') as testwritefile:
    print(testwritefile.read())
# Out:
# Overwrite
# This is line C
# This is line D
# This is line E

# %%
with open('Example2.txt', 'r') as testwritefile:
    print(testwritefile.read())
# Out:
# Overwrite
# This is line C
# This is line D
# This is line E

# %% [markdown]
# ### Additional modes
#
# **r+** -> reads & writes file; can't truncate the file
#
# **w+** -> writes & reads; truncates the file
#
# **a+** -> appends & reads; creates a new file if none exists
#
# Consider that:
# .tell() - returns the current position in bytes
#
# .seek(offset,from) - changes the position by 'offset' bytes with respect to 'from'. From can take the value of 0,1,2 corresponding to beginning, relative to current position and end
#
# .truncate() method at the end of your data. This will reduce the file to your data and delete everything that follows.

# %%
with open('Example2.txt', 'a+') as testwritefile:
    testwritefile.write("This is line E\n")
    print(testwritefile.read())

# %%
#.tell()

#.seek(offset,from) 

with open('Example2.txt', 'a+') as testwritefile:
    print("Initial Location: {}".format(testwritefile.tell()))
    
    data = testwritefile.read()
    if (not data):  #empty strings return false in python
            print('Read nothing') 
    else: 
            print(testwritefile.read())
            
    testwritefile.seek(0,0) # move 0 bytes from beginning.
    
    print("\nNew Location : {}".format(testwritefile.tell()))
    data = testwritefile.read()
    if (not data): 
            print('Read nothing') 
    else: 
            print(data)
    
    print("Location after read: {}".format(testwritefile.tell()) )
# Out:
# Initial Location: 70
# Read nothing
#
# New Location : 0
# Overwrite
# This is line C
# This is line D
# This is line E
# This is line E
#
# Location after read: 70

# %%
# .truncate() 

with open('Example2.txt', 'r+') as testwritefile:
    data = testwritefile.readlines()
    testwritefile.seek(0,0) #write at beginning of file
   
    testwritefile.write("Line 1" + "\n")
    testwritefile.write("Line 2" + "\n")
    testwritefile.write("Line 3" + "\n")
    testwritefile.write("finished\n")
    #Uncomment the line below
    #testwritefile.truncate()
    testwritefile.seek(0,0)
    print(testwritefile.read())
# Out:
# Line 1
# Line 2
# Line 3
# finished
# is line D
# This is line E
# This is line E

# %% [markdown]
# ### Copy a File

# %%
with open('Example2.txt','r') as readfile:
    with open('Example3.txt','w') as writefile:
          for line in readfile:
                writefile.write(line)

# %%
with open('Example3.txt','r') as testwritefile:
    print(testwritefile.read())
# Out:
# Line 1
# Line 2
# Line 3
# finished
# is line D
# This is line E
# This is line E

# %% [markdown]
# ### Ejercicio

# %%
from random import randint as rnd

memReg = 'members.txt'
exReg = 'inactive.txt'
fee =('yes','no')

def genFiles(current,old):
    with open(current,'w+') as writefile: 
        writefile.write('Membership No  Date Joined  Active  \n')
        data = "{:^13}  {:<11}  {:<6}\n"

        for rowno in range(20):
            date = str(rnd(2015,2020))+ '-' + str(rnd(1,12))+'-'+str(rnd(1,25))
            writefile.write(data.format(rnd(10000,99999),date,fee[rnd(0,1)]))


    with open(old,'w+') as writefile: 
        writefile.write('Membership No  Date Joined  Active  \n')
        data = "{:^13}  {:<11}  {:<6}\n"
        for rowno in range(3):
            date = str(rnd(2015,2020))+ '-' + str(rnd(1,12))+'-'+str(rnd(1,25))
            writefile.write(data.format(rnd(10000,99999),date,fee[1]))


genFiles(memReg,exReg)

# %% [markdown]
# ```
# # Code instructions:
#
# def cleanFiles(currentMem, exMem):
#     # TODO: Open the currentMem file as in r+ mode
#         #TODO: Open the exMem file in a+ mode
#
#         #TODO: Read each member in the currentMem (1 member per row) file into a list.
#         # Hint: Recall that the first line in the file is the header.
#
#         #TODO: iterate through the members and create a new list of the innactive members
#
#         # Go to the beginning of the currentMem file
#         # TODO: Iterate through the members list.
#         # If a member is inactive, add them to exMem, otherwise write them into currentMem
#
#
#
#     pass # Remove this line when done implementation
#
#
# # The code below is to help you view the files.
# # Do not modify this code for this exercise.
# memReg = 'members.txt'
# exReg = 'inactive.txt'
# cleanFiles(memReg,exReg)
#
#
# headers = "Membership No  Date Joined  Active  \n"
# with open(memReg,'r') as readFile:
#     print("Active Members: \n\n")
#     print(readFile.read())
#
# with open(exReg,'r') as readFile:
#     print("Inactive Members: \n\n")
#     print(readFile.read())
# ```

# %%
def cleanFiles(currentMem, exMem):
    with open(currentMem,"r+") as writeFile: #TODO: Open the currentMem file as in r+ mode
        with open(exMem,"a+") as appendFile: #TODO: Open the exMem file in a+ mode

          #TODO: Read each member in the currentMem (1 member per row) file into a list.
          writeFile.seek(0) #Get the data
          members = writeFile.readlines()
          header = members[0] #Removes header
          members.pop(0)

          inactive = [member for member in members if ("no" in member)] #TODO: iterate through the members and create a new list of the innactive members

          '''
          #TODO: iterate through the members and create a new list of the innactive members
          The above is the same as 

          for member in members:
          if 'no' in member:
            inactive.append(member)          
          '''
          writeFile.seek(0) # Go to the beginning of the currentMem file
          writeFile.write(header)
          for member in members: # TODO: Iterate through the members list.
              if (member in inactive): # If a member is inactive, add them to exMem, otherwise write them into currentMem
                  appendFile.write(member)
              else:
                  writeFile.write(member)      
          writeFile.truncate()

# The code below is to help you view the files.
# Do not modify this code for this exercise.
memReg = 'members.txt'
exReg = 'inactive.txt'
cleanFiles(memReg,exReg)


headers = "Membership No  Date Joined  Active  \n"
with open(memReg,'r') as readFile:
    print("Active Members: \n\n")
    print(readFile.read())
    
with open(exReg,'r') as readFile:
    print("Inactive Members: \n\n")
    print(readFile.read())
# Out:
# Active Members:
#
#
# Membership No  Date Joined  Active
#     42733      2020-7-17    yes
#     74718      2018-10-20   yes
#     82503      2016-4-16    yes
#     26449      2018-12-7    yes
#     83372      2018-4-12    yes
#     10623      2018-11-2    yes
#     67593      2017-8-11    yes
#     30128      2016-5-19    yes
#     55105      2016-11-14   yes
#     55248      2019-1-25    yes
#
# Inactive Members:
#
#
# Membership No  Date Joined  Active
#     22746      2019-10-7    no
#     65715      2016-6-21    no
#     69297      2017-9-16    no
#     23611      2020-1-21    no
#     25576      2020-4-9     no
#     13275      2015-3-7     no
#     30908      2017-12-4    no
#     86832      2015-3-3     no
#     47718      2015-1-7     no
#     85209      2017-8-9     no
#     37277      2017-5-20    no
#     45918      2016-4-8     no
#     84471      2015-1-4     no

# %%
#Code to test solution

def testMsg(passed):
    if passed:
       return 'Test Passed'
    else :
       return 'Test Failed'

testWrite = "testWrite.txt"
testAppend = "testAppend.txt" 
passed = True

genFiles(testWrite,testAppend)

with open(testWrite,'r') as file:
    ogWrite = file.readlines()

with open(testAppend,'r') as file:
    ogAppend = file.readlines()

try:
    cleanFiles(testWrite,testAppend)
except:
    print('Error')

with open(testWrite,'r') as file:
    clWrite = file.readlines()

with open(testAppend,'r') as file:
    clAppend = file.readlines()
        
# checking if total no of rows is same, including headers

if (len(ogWrite) + len(ogAppend) != len(clWrite) + len(clAppend)):
    print("The number of rows do not add up. Make sure your final files have the same header and format.")
    passed = False
    
for line in clWrite:
    if  'no' in line:
        passed = False
        print("Inactive members in file")
        break
    else:
        if line not in ogWrite:
            print("Data in file does not match original file")
            passed = False
print ("{}".format(testMsg(passed)))
# Out:
# Test Passed

# %% [markdown]
# # Tema 3 - Pandas: Loading Data
# Introducción a la librería

# %% [markdown]
# ## Importar librería
#
# ```
# import pandas as pd
# ```

# %% [markdown]
# ## Lectura de archivos con libraría Pandas

# %% [markdown]
# ### Lectura de CSV
#
# Lectura de un file CSV con Pandas con función **pd.read_csv()**
#
# *Después de pd se puede insertar cualquier otra función de Pandas*
#
# ```
# import pandas as pd
#
# csv_path="file1.csv"
# df = pd.read_csv(csv_path)
#
# ```
#
# CSV file a **Data frame**
#
# ```
# csv_path="file1.csv" #Stores path of the csv y se usa como argumento para la función de leer de la siguiente línea
# df = pd.read_csv(csv_path) #El resultado se va a guardar en la variable df (DATA FRAME)
#
# ```
#
# Para leer los primeros 5 registros del df, se usa **df.head()**
#
# ```
# csv_path="file1.csv"
# df = pd.read_csv(csv_path)
# df.head()
#
# ```
# El **resultado** es el siguiente:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Lectura de excel
#
# Lo que cambia en el código es el tipo de archivo y su extensión
#
# ```
# xlsx_path="file1.xls"
# df = pd.read_excel(xlsx_path)
# df.head ()
# ```
#
# El **resultado** es un DATA FRAME
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Data frames
#
# Los data frames son **conjunto de datos** que se encuentran en formato de tabla (filas y columnas)
#
# Ejemplo:
#
# ![image.png](data:image/png;base64,...)
#
# Se pueden crear data frames a través de **Diccionarios**, donde **Keys** son las etiquetas de las columnas y los **values** son las filas.
#
# Para crearlos, se utiliza la función **pd.DataFrame(Variable)**
#
# ```
# songs = {"Album":["Thriller", "Back in Black", "The Dark Side of the Moon", \ "The Bodyguard", "Bat Out of Hell"], "Released":[1982, 1980, 1973, 1992, 1997], "Lenght":["00:42:19","00:42:11","00:42:49","00:57:44","00:46:33"]}
#
# songs_frame = pd.DataFrame(songs)
#
# ```
# Relación entre KEYS & HEADERS:
#
# ![image.png](data:image/png;base64,...)
#
# Relación de las listas con respecto a las filas:
#
#
# ![image.png](data:image/png;base64,...)
#
# Se puede crear un **nuevo data frame** de una sola columna colocando en **doble [[]] el nombre del key** en cuestión, como se muestra en el siguiente código:
#
# ```
# x = df[["Lenght"]]
#
# ```
# El **resultado** sería el siguiente:
#
# ![image.png](data:image/png;base64,...)
#
# En dado caso de que se busque realizar esto con varas **KEYS**, sólamente se enlistan dentro de los [[]], como se muestra en el siguiente código:
#
# ```
# y = df[["Artist", "Lenghth", "Genre"]]
# ```
#
# El **resultado**, nuevamente, será una **nueva data frame** con el contenido solicitado dentro del código:
#
# ![image.png](data:image/png;base64,...)
#
# Para acceder a los contenidos dentro de nuestro **data frame**, se utiliza el método **ix** y, dependiendo de lo que se quiera acceder, se escribe dentro de las coordenadas:
#
# ```
# #Primera fila y primera columna
# df.ix[0,0] #Nos va a arrojar"Michael Jackson", porque busca primera fila y primera columna
#
# #Segunda fila y primera columna
# df.ix[1,0] #Nos va a arrojar "AC/DC", porque nos busca segunda fila y primera columna
#
# #Primera fila y tercera columna
# df.ix[0,2] #Nos va a arrojar 1982, porque busca primera fila y tercera columna
#
# #Segunda fila y tercera columna
# df.ix[1,2] #Nos va a arrojar 1980, porque busca segunda fila y tercera columna
# ```
# Otra alternativa es utilizar el **nombre de la comumna**, como se muestra a continuación:
#
# ```
# #Primera fila y columna "Artist"
# df.ix[0,"Artist"] #Nos va a arrojar"Michael Jackson"
#
# #Segunda fila y columna "Artist"
# df.ix[1,"Artist"] #Nos va  arrojar "AC/DC"
#
# #Primera fila y  columna "Released"
# df.ix[0,"Released"] #Nos va a arrojar 1982
#
# #Segunda fila y  columna "Released"
# df.ix[1,"Released"] #Nos va a arrojar 1980
# ```
