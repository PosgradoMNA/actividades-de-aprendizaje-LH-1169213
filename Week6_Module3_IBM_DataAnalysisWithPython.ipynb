# %% [markdown]
# <a href="https://colab.research.google.com/github/PosgradoMNA/actividades-de-aprendizaje-LH-1169213/blob/main/Week6_Module3_IBM_DataAnalysisWithPython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Module 3: Working with Numpy arrays & simple APIs
# ## Laura Elena Hernández Mata
# ## A01169213
# ### Semana 6

# %% [markdown]
# ## Módulo 3: Exploratory Data Analysis

# %% [markdown]
# Exploratory Data Analysis ("EDA") is an approach to analyze data in order to:
#
# *   Summarize main characteristics of the data-gain: better understanding of the dataset
# *   Uncover relationships between different variables
# *   Extract important variables for the problem we are trying to solve

# %% [markdown]
# ## Descriptive statistics

# %% [markdown]
# *   Describe basic features of data
# *   Summaries about the samples and measures of the data
#
# Métodos para **resumir** estadísticas con Pandas:
#
# ```
# df.describe()
# ```
# El resultado es el siguiente:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Para **resumir los datos categóricos** podemos utilizar lo siguiente:
#
# ```
# variable = df.value_counts()
# ```
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Box plots**
#
# Las cajas funcionan de la siguiente manera:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Cuando se grafica, se muestra de la siguiente manera:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Scatter plot**
#
# *   Cada observación es un punto en la gráfica
# *   La gráfica muestra la relación entre dos variables
#       *    Predictor/Independent variables on x-axis.
#       *    Target/Dependent variables on y-axis.
#
# El resultado y código son los siguietnes:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Si la pendiente se muestra como ocurre a continuación, quiere decir que hay una relación positiva lineal entre las dos variables:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Grouping Data

# %% [markdown]
# **Group by**

# %% [markdown]
# El siguiente código se puede aplicar en variables categóricas, se pueden agrupar single or multiple variables.
#
# ```
# df.groupby()
# ```
# Un ejemplo es como el que se muestra a continuación:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Pivot table**

# %% [markdown]
# Tiene una variable en columnas y otra en filas. Y se codifica y visualiza de la siguiente manera:
#
# ```
# var_pivot = df.pivot(index="Variable en filas", columnas="variable")
# ```
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Heatmap**
#
# Permite mostrar una tabla pivote y mostrar múltiples variables junto con su relación, como se muestra a continuación
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## ANOVA

# %% [markdown]
# **ANOVA** es **An**alysis **o**f **Va**riance
#
# *   Comparación estadística entre grupos
# *   Permite conocer la correlación entre las variables
# *   Los resultados son:
#       *    **F-test score:** variation between sample group means divided by variation within each sample group
#       **Correlation is weak**
#       ![image.png](data:image/png;base64,...)
#       **Correlation is strong**
#       ![image.png](data:image/png;base64,...)
#       *    **p-value:** confidence degree (muestra si el resultado es estadísticamente significativo.

# %% [markdown]
# Para realizar el ANOVA, se realiza el siguiente código:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Cuando el F-test value es grande y el p-value es pequeño, hay correlación entre la variable categórica y la otra variable**

# %% [markdown]
# ## Correlación

# %% [markdown]
# La correlación es una métrica estadística que permite cuantificar **qué tan independientes son dos variables diferentes.**
#
# Es decir, qué tanto afecta el cambio en una variable respecto a la otra.
#
# **Correlation doesn't imply causation**

# %% [markdown]
# **Correlación positiva en scatter plot**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Correlación negativa entre variables**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Weak correlation** (No serviría para predecir los valores)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Correlación de Pearson

# %% [markdown]
# La correlación de Pearson va a medir la fuerza de la correlación entre dos features y se obtiene:
#
# *   **Correlation coefficient**
#       *    **Cercano a +1** Relación positiva
#       *    **Cercano a -1** Relación negativa
#       *    **Cercano a 0** No hay relación
# *   **P-value:** *Nos indica la certeza de la correlación calculada*
#       *    **P value < 0.001** ***STRONG*** certainity
#       *    **P value < 0.05** Moderate
#       *    **P value < 0.1** Weak
#       *    **P value > 0.1** ***NO*** certainity

# %% [markdown]
# **Fuerte Correlación**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Dependencia graficada:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Cálculo en Python, donde hay fuerte correlación:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **CORRELATION HEATMAP**

# %% [markdown]
# El heatmap de correlación permite conocer la relación entre variables.
#
# Los colores muestran el grado de correlación.
#
# En la lína roja se muestra los que están altamente correlacionados.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # LAB 3

# %% [markdown]
# 1. Import Data from Module 2

# %%
# INSTALACIÓN DE LIBRERÍAS

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# IMPORT DATA

df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/automobileEDA.csv")

# %%
# REVISIÓN DE DATA

df.head()
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# 1  convertible          rwd           front        88.6  0.811148  ...
# 2    hatchback          rwd           front        94.5  0.822681  ...
# 3        sedan          fwd           front        99.8  0.848630  ...
# 4        sedan          4wd           front        99.4  0.848630  ...
#
#    compression-ratio  horsepower  peak-rpm city-mpg highway-mpg    price  \
# ...

# %% [markdown]
# 2. Analyzing Individual Feature Patterns Using Visualization

# %%
print(df.dtypes)
# Out:
# symboling              int64
# normalized-losses      int64
# make                  object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# city-L/100km         float64
# horsepower-binned     object
# diesel                 int64
# gas                    int64
# dtype: object

# %% [markdown]
# **Question 1**

# %%
# What is the data type of the column "peak-rpm"?

df['peak-rpm'].dtypes
# Out:
# dtype('float64')

# %%
# The diagonal elements are always one.

df.corr()
# Out:
#                    symboling  normalized-losses  wheel-base    length  \
# symboling           1.000000           0.466264   -0.535987 -0.365404
# normalized-losses   0.466264           1.000000   -0.056661  0.019424
# wheel-base         -0.535987          -0.056661    1.000000  0.876024
# length             -0.365404           0.019424    0.876024  1.000000
# width              -0.242423           0.086802    0.814507  0.857170
# height             -0.550160          -0.373737    0.590742  0.492063
# curb-weight        -0.233118           0.099404    0.782097  0.880665
# engine-size        -0.110581           0.112360    0.572027  0.685025
# bore               -0.140019          -0.029862    0.493244  0.608971
# stroke             -0.008245           0.055563    0.158502  0.124139
# compression-ratio  -0.182196          -0.114713    0.250313  0.159733
# horsepower          0.075819           0.217299    0.371147  0.579821
# ...

# %% [markdown]
# **Question 2**

# %%
# Find the correlation between the following columns: bore, stroke, compression-ratio, and horsepower.

df[['bore','stroke','compression-ratio','horsepower']].corr()
# Out:
#                        bore    stroke  compression-ratio  horsepower
# bore               1.000000 -0.055390           0.001263    0.566936
# stroke            -0.055390  1.000000           0.187923    0.098462
# compression-ratio  0.001263  0.187923           1.000000   -0.214514
# horsepower         0.566936  0.098462          -0.214514    1.000000

# %% [markdown]
# ## **Continuous Numerical Variables:**

# %% [markdown]
# ### POSITIVE LINEAR RELATIONSHIP

# %%
sns.regplot(x="engine-size", y="price", data=df)
plt.ylim(0,)
# Out:
# (0.0, 52860.92267446386)

# %%
df[["engine-size", "price"]].corr()
# Out:
#              engine-size     price
# engine-size     1.000000  0.872335
# price           0.872335  1.000000

# %%
sns.regplot(x="highway-mpg", y="price", data=df)

# %%
df[['highway-mpg', 'price']].corr()
# Out:
#              highway-mpg     price
# highway-mpg     1.000000 -0.704692
# price          -0.704692  1.000000

# %% [markdown]
# ### WEAK LINEAR RELATIONSHIP

# %%
sns.regplot(x="peak-rpm", y="price", data=df)

# %%
df[['peak-rpm','price']].corr()
# Out:
#           peak-rpm     price
# peak-rpm  1.000000 -0.101616
# price    -0.101616  1.000000

# %% [markdown]
# **QUESTION 3A**

# %%
df[["stroke","price"]].corr()
# Out:
#          stroke    price
# stroke  1.00000  0.08231
# price   0.08231  1.00000

# %% [markdown]
# **Question 3b**

# %%
sns.regplot(x="stroke", y="price", data=df)

# %% [markdown]
# ## Categorical variables

# %%
sns.boxplot(x="body-style", y="price", data=df)

# %%
sns.boxplot(x="engine-location", y="price", data=df)

# %%
sns.boxplot(x="drive-wheels", y="price", data=df)
