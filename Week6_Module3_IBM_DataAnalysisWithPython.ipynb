# %% [markdown]
# <a href="https://colab.research.google.com/github/PosgradoMNA/actividades-de-aprendizaje-LH-1169213/blob/main/Week6_Module3_IBM_DataAnalysisWithPython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Module 3: Working with Numpy arrays & simple APIs
# ## Laura Elena Hernández Mata
# ## A01169213
# ### Semana 6

# %% [markdown]
# ## Módulo 3: Exploratory Data Analysis

# %% [markdown]
# Exploratory Data Analysis ("EDA") is an approach to analyze data in order to:
#
# *   Summarize main characteristics of the data-gain: better understanding of the dataset
# *   Uncover relationships between different variables
# *   Extract important variables for the problem we are trying to solve

# %% [markdown]
# ## Descriptive statistics

# %% [markdown]
# *   Describe basic features of data
# *   Summaries about the samples and measures of the data
#
# Métodos para **resumir** estadísticas con Pandas:
#
# ```
# df.describe()
# ```
# El resultado es el siguiente:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Para **resumir los datos categóricos** podemos utilizar lo siguiente:
#
# ```
# variable = df.value_counts()
# ```
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Box plots**
#
# Las cajas funcionan de la siguiente manera:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Cuando se grafica, se muestra de la siguiente manera:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Scatter plot**
#
# *   Cada observación es un punto en la gráfica
# *   La gráfica muestra la relación entre dos variables
#       *    Predictor/Independent variables on x-axis.
#       *    Target/Dependent variables on y-axis.
#
# El resultado y código son los siguietnes:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Si la pendiente se muestra como ocurre a continuación, quiere decir que hay una relación positiva lineal entre las dos variables:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Grouping Data

# %% [markdown]
# **Group by**

# %% [markdown]
# El siguiente código se puede aplicar en variables categóricas, se pueden agrupar single or multiple variables.
#
# ```
# df.groupby()
# ```
# Un ejemplo es como el que se muestra a continuación:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Pivot table**
